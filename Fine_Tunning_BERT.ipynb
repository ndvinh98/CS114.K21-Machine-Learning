# %% [markdown]
# <a href="https://colab.research.google.com/github/koyomin9zx/CS114.K21-Machine-Learning/blob/master/Fine_Tunning_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install pytorch-transformers
# !git clone https://github.com/huggingface/transformers
# !pip install -r /content/transformers/examples/requirements.txt
# !git clone https://github.com/kamalkraj/BERT-SQuAD.git

# %%
# !ln -s /content/drive/'My Drive'/data

# %%
#training
# !python /content/transformers/examples/run_squad.py \
  --model_type bert \
  --model_name_or_path bert-base-multilingual-cased \
  --do_train \
  --do_eval \
  --train_file /content/data/dataset/train_translated_squad_100.json \
  --predict_file /content/data/dataset/test.json \
  --per_gpu_train_batch_size 12 \
  --learning_rate 3e-5 \
  --num_train_epochs 2.0 \
  --max_seq_length 384 \
  --doc_stride 128 \
  --output_dir /content/data/pytorch_pretrain_vi
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  35% 2514/7255 [1:14:24<2:16:34,  1.73s/it]
# Iteration:  35% 2515/7255 [1:14:26<2:16:39,  1.73s/it]
# Iteration:  35% 2516/7255 [1:14:27<2:16:38,  1.73s/it]
# Iteration:  35% 2517/7255 [1:14:29<2:16:41,  1.73s/it]
# Iteration:  35% 2518/7255 [1:14:31<2:16:32,  1.73s/it]
# Iteration:  35% 2519/7255 [1:14:33<2:16:44,  1.73s/it]
# Iteration:  35% 2520/7255 [1:14:34<2:16:41,  1.73s/it]
# Iteration:  35% 2521/7255 [1:14:36<2:16:30,  1.73s/it]
# Iteration:  35% 2522/7255 [1:14:38<2:16:23,  1.73s/it]
# Iteration:  35% 2523/7255 [1:14:40<2:16:10,  1.73s/it]
# Iteration:  35% 2524/7255 [1:14:41<2:16:22,  1.73s/it]
# Iteration:  35% 2525/7255 [1:14:43<2:16:22,  1.73s/it]
# Iteration:  35% 2526/7255 [1:14:45<2:16:14,  1.73s/it]
# Iteration:  35% 2527/7255 [1:14:47<2:16:19,  1.73s/it]
# Iteration:  35% 2528/7255 [1:14:48<2:16:18,  1.73s/it]
# Iteration:  35% 2529/7255 [1:14:50<2:16:29,  1.73s/it]
# ...
